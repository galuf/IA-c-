# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.loc[data['gender'] == 'female', 'gender'] = '0'
data.loc[data['gender'] == 'male', 'gender'] = '1'

# %%
data.head()
# Out:
#   gender race/ethnicity parental level of education         lunch  \
# 0      0        group B           bachelor's degree      standard
# 1      0        group C                some college      standard
# 2      0        group B             master's degree      standard
# 3      1        group A          associate's degree  free/reduced
# 4      1        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
data.loc[data['race/ethnicity'] == 'group A', 'race/ethnicity'] = '0'
data.loc[data['race/ethnicity'] == 'group B', 'race/ethnicity'] = '1'
data.loc[data['race/ethnicity'] == 'group C', 'race/ethnicity'] = '2'
data.loc[data['race/ethnicity'] == 'group D', 'race/ethnicity'] = '3'
data.loc[data['race/ethnicity'] == 'group E', 'race/ethnicity'] = '4'

# %%
data.head()
# Out:
#   gender race/ethnicity parental level of education         lunch  \
# 0      0              1           bachelor's degree      standard
# 1      0              2                some college      standard
# 2      0              1             master's degree      standard
# 3      1              0          associate's degree  free/reduced
# 4      1              2                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# some high school -> secundaria imcompleta : 0
# high school -> Secundaria : 1
# some college -> educacion Superior Incompleta : 2
# associate's degree -> Tecnico : 3
# bachelor's degree -> Licensiatura : 4
# master's degree -> magister : 5

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data.loc[data['parental level of education'] == 'some high school', 'parental level of education'] = '0'
data.loc[data['parental level of education'] == 'high school', 'parental level of education'] = '1'
data.loc[data['parental level of education'] == 'some college', 'parental level of education'] = '2'
data.loc[data['parental level of education'] == "associate's degree", 'parental level of education'] = '3'
data.loc[data['parental level of education'] == "bachelor's degree", 'parental level of education'] = '4'
data.loc[data['parental level of education'] == "master's degree", 'parental level of education'] = '5'

# %%
data.head()
# Out:
#   gender race/ethnicity parental level of education         lunch  \
# 0      0              1                           4      standard
# 1      0              2                           2      standard
# 2      0              1                           5      standard
# 3      1              0                           3  free/reduced
# 4      1              2                           2      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
data.loc[data['lunch'] == 'standard', 'lunch'] = '1'
data.loc[data['lunch'] == 'free/reduced', 'lunch'] = '0'

# %%
data.head()
# Out:
#   gender race/ethnicity parental level of education lunch  \
# 0      0              1                           4     1
# 1      0              2                           2     1
# 2      0              1                           5     1
# 3      1              0                           3     0
# 4      1              2                           2     1
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
data.loc[data['test preparation course'] == 'none', 'test preparation course'] = '0'
data.loc[data['test preparation course'] == 'completed', 'test preparation course'] = '1'

# %%
data.head()
# Out:
#   gender race/ethnicity parental level of education lunch  \
# 0      0              1                           4     1
# 1      0              2                           2     1
# 2      0              1                           5     1
# 3      1              0                           3     0
# 4      1              2                           2     1
#
#   test preparation course  math score  reading score  writing score
# 0                       0          72             72             74
# 1                       1          69             90             88
# 2                       0          90             95             93
# 3                       0          47             57             44
# 4                       0          76             78             75

# %%
data.head()
# Out:
#   gender race/ethnicity parental level of education lunch  \
# 0      0              1                           4     1
# 1      0              2                           2     1
# 2      0              1                           5     1
# 3      1              0                           3     0
# 4      1              2                           2     1
#
#   test preparation course  math score  reading score  writing score
# 0                       0          72             72             74
# 1                       1          69             90             88
# 2                       0          90             95             93
# 3                       0          47             57             44
# 4                       0          76             78             75

# %%
data.drop(['reading score','writing score'],axis=1)
# Out:
#     gender race/ethnicity parental level of education lunch  \
# 0        0              1                           4     1
# 1        0              2                           2     1
# 2        0              1                           5     1
# 3        1              0                           3     0
# 4        1              2                           2     1
# ..     ...            ...                         ...   ...
# 995      0              4                           5     1
# 996      1              2                           1     0
# 997      0              2                           1     0
# 998      0              3                           2     1
# 999      0              3                           2     0
#
#     test preparation course  math score
# 0                         0          72
# 1                         1          69
# 2                         0          90
# 3                         0          47
# ...

# %%
df_shuffled=data.sample(frac=1).reset_index(drop=True)

# %%
df_shuffled.head()
# Out:
#   gender race/ethnicity parental level of education lunch  \
# 0      0              2                           3     1
# 1      1              2                           3     1
# 2      0              2                           4     1
# 3      1              3                           2     0
# 4      0              2                           4     0
#
#   test preparation course  math score  reading score  writing score
# 0                       1          55             72             79
# 1                       0          84             80             80
# 2                       1          59             64             75
# 3                       0          49             57             46
# 4                       1          43             51             54

# %%
df_shuffled.to_csv('PrediccionNotasClean.csv')
